# %% [markdown]
# Install Pandas
#
# pip install pandas

# %% [markdown]
# Import Pandas

# %%
import pandas as pd

# %% [markdown]
# Read the data

# %% [markdown]
# File Handling
#
# ```
# try:
#   data = pd.read_csv('path_of_file')
# except FileNotFoundError as e:
#   print("File not found:", e)
# ```

# %%
data = pd.read_csv('../dataset/titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %% [markdown]
# Display the top 5 records in the data

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 5                          Svensson, Mr. Johan Cervin    male  14.0      0
# 6                                Connolly, Miss. Kate  female  30.0      0
# 7                        Caldwell, Mr. Albert Francis    male  26.0      1
# 8           Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 9                             Davies, Mr. John Samuel    male  21.0      2
# 10                                   Ilieff, Mr. Ylio    male   NaN      0
# 11                         Jones, Mr. Charles Cresson    male  46.0      0
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 13                               Howard, Mr. Benjamin    male  63.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
#
#     Parch       Ticket     Fare Cabin Embarked
# 0       0       330911   7.8292   NaN        Q
# 1       0       363272   7.0000   NaN        S
# 2       0       240276   9.6875   NaN        Q
# 3       0       315154   8.6625   NaN        S
# 4       1      3101298  12.2875   NaN        S
# 5       0         7538   9.2250   NaN        S
# 6       0       330972   7.6292   NaN        Q
# 7       1       248738  29.0000   NaN        S
# 8       0         2657   7.2292   NaN        C
# 9       0    A/4 48871  24.1500   NaN        S
# 10      0       349220   7.8958   NaN        S
# 11      0          694  26.0000   NaN        S
# 12      0        21228  82.2667   B45        S
# 13      0        24065  26.0000   NaN        S
# 14      0  W.E.P. 5734  61.1750   E31        S

# %% [markdown]
# Display the last few records in the dataframe

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
data.tail(15)
# Out:
#      PassengerId  Survived  Pclass  \
# 403         1295         0       1
# 404         1296         0       1
# 405         1297         0       2
# 406         1298         0       2
# 407         1299         0       1
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 403                           Carrau, Mr. Jose Pedro    male  17.0      0
# 404                     Frauenthal, Mr. Isaac Gerald    male  43.0      1
# 405     Nourney, Mr. Alfred (Baron von Drachstedt")"    male  20.0      0
# 406                        Ware, Mr. William Jeffery    male  23.0      1
# 407                       Widener, Mr. George Dunton    male  50.0      1
# 408                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# 414                     Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                     Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                              Ware, Mr. Frederick    male   NaN      0
# 417                         Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 403      0              113059   47.1000   NaN        S
# 404      0               17765   27.7208   D40        C
# 405      0       SC/PARIS 2166   13.8625   D38        C
# 406      0               28666   10.5000   NaN        S
# 407      1              113503  211.5000   C80        C
# 408      0              334915    7.7208   NaN        Q
# 409      1  SOTON/O.Q. 3101315   13.7750   NaN        S
# 410      0              365237    7.7500   NaN        Q
# 411      0               19928   90.0000   C78        Q
# 412      0              347086    7.7750   NaN        S
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %% [markdown]
# Data Structure: Dataframe

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data['PassengerId'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Series in Depth: It's a one dimensional array-like structure in Pandas that can hold a sequence of value of any data type. Each value in a Series is linked with a associated label, known as the index. You can also customize the index labels in the series.

# %% [markdown]
# Create a series from scalar value with the custom index

# %%
series_scalar = pd.Series(10, index=['a', 'b', 'c', 'd', 'e', 'f'])
print(series_scalar)
# Out:
# a    10
# b    10
# c    10
# d    10
# e    10
# f    10
# dtype: int64

# %%
series_scalar['e']
# Out:
# np.int64(10)

# %%
data = [10, 20, 30, 40, 50, 60, 70]
series_list = pd.Series(data)
print(series_list)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# dtype: int64

# %%
import numpy as np
data_array = np.array([10, 20, 30, 40, 50, 60])
series_custom_array = pd.Series(data_array, index=['a', 'b', 'c', 'd', 'e', 'f'])
series_custom_array
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# dtype: int64

# %%
data_dict = {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': 50}
series_dict = pd.Series(data_dict)
series_dict
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# Slicing

# %%
series_dict[1:4]
# Out:
# b    20
# c    30
# d    40
# dtype: int64

# %%
series_dict['b':'d']
# Out:
# b    20
# c    30
# d    40
# dtype: int64

# %% [markdown]
# Attributes in Series Data Structure

# %%
data = ['New Delhi', 'Washington', 'London', 'Paris']
index = ['India', 'USA', 'UK', 'France']

series_capital_country = pd.Series(data, index=index)
print(series_capital_country)
# Out:
# India      New Delhi
# USA       Washington
# UK            London
# France         Paris
# dtype: object

# %%
print("Index of the series_capital_country")
print(series_capital_country.index)
# Out:
# Index of the series_capital_country
# Index(['India', 'USA', 'UK', 'France'], dtype='object')

# %%
print(type(series_capital_country.index))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
print("Values of the series_capital_country")
print(series_capital_country.values)
# Out:
# Values of the series_capital_country
# ['New Delhi' 'Washington' 'London' 'Paris']

# %% [markdown]
# Dtype is data type of each element in that type of data structure

# %%
print("Data type of the series_capital_country")
print(series_capital_country.dtype)
# Out:
# Data type of the series_capital_country
# object

# %%
print("Shape of the series_capital_country")
print(series_capital_country.shape)
# Out:
# Shape of the series_capital_country
# (4,)

# %%
print("Size of the series_capital_country")
print(series_capital_country.size)
# Out:
# Size of the series_capital_country
# 4

# %%
print("Is series_capital_country empty?")
print(series_capital_country.empty)
# Out:
# Is series_capital_country empty?
# False

# %%
print("Is series_capital_country contains NaN?")
print(series_capital_country.hasnans)
# Out:
# Is series_capital_country contains NaN?
# False

# %%
print("Is series_capital_country contains unique elements?")
print(series_capital_country.is_unique)
# Out:
# Is series_capital_country contains unique elements?
# True

# %%
print("Dimensions of the series_capital_country")
print(series_capital_country.ndim)
# Out:
# Dimensions of the series_capital_country
# 1

# %%
empty_series = pd.Series()
print(empty_series)
# Out:
# Series([], dtype: object)

# %%
print("Is empty_series empty?")
print(empty_series.empty)
# Out:
# Is empty_series empty?
# True

# %% [markdown]
# Methods in Series Data Structure

# %%
series_capital_country.head(2)
# Out:
# India     New Delhi
# USA      Washington
# dtype: object

# %%
series_capital_country.tail(2)
# Out:
# UK        London
# France     Paris
# dtype: object

# %%
marks = [85, 60, 74, 66, 89, 91]
students = ['Ram', 'Priya', 'Rashmi', 'Vidushi', 'Mohit', 'Karan']

series_students = pd.Series(marks, index=students)
print(series_students)
# Out:
# Ram        85
# Priya      60
# Rashmi     74
# Vidushi    66
# Mohit      89
# Karan      91
# dtype: int64

# %% [markdown]
# To get the descriptive statistics of the given data

# %%
series_students.describe()
# Out:
# count     6.000000
# mean     77.500000
# std      12.817956
# min      60.000000
# 25%      68.000000
# 50%      79.500000
# 75%      88.000000
# max      91.000000
# dtype: float64

# %% [markdown]
# value_counts()

# %%
series_students.value_counts()
# Out:
# 85    1
# 60    1
# 74    1
# 66    1
# 89    1
# 91    1
# Name: count, dtype: int64

# %% [markdown]
# sort_values()

# %%
series_students.sort_values()
# Out:
# Priya      60
# Vidushi    66
# Rashmi     74
# Ram        85
# Mohit      89
# Karan      91
# dtype: int64

# %% [markdown]
# drop()

# %% [markdown]
# ```
# series_students = series_students.drop('Karan')
# series_students
# ```

# %%
series_students.drop('Karan', inplace=True)

# %%
series_students
# Out:
# Ram        85
# Priya      60
# Rashmi     74
# Vidushi    66
# Mohit      89
# dtype: int64

# %% [markdown]
# isnull() -> Detect the missing values

# %%
print(series_students.isnull())
# Out:
# Ram        False
# Priya      False
# Rashmi     False
# Vidushi    False
# Mohit      False
# dtype: bool

# %%
print(series_students.isnull().sum())
# Out:
# 0

# %% [markdown]
# Task: Mathematical Operations on Series

# %% [markdown]
# 1. Addition of two Series
#
# 2. Subtraction of two Series
#
# 3. Multiplication of two Series
#
# 4. Division of two Series

# %%
series_students['Karan'] = 91
series_students
# Out:
# Ram        85
# Priya      60
# Rashmi     74
# Vidushi    66
# Mohit      89
# Karan      91
# dtype: int64

# %% [markdown]
# Task: Simulate the same approach for a dataframe and you need to cover all the attributes and methods for the dataframe

# %% [markdown]
# Import all the required libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Read the data

# %%
data = pd.read_excel('../dataset/customers.xlsx')
data.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Desktop/learn/pandas_learn/venv/lib/python3.13/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /usr/local/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data = pd.read_excel('../dataset/customers.xlsx')
#       2 data.head()
#
# File ~/Desktop/learn/pandas_learn/venv/lib/python3.13/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~/Desktop/learn/pandas_learn/venv/lib/python3.13/site-packages/pandas/io/excel/_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File ~/Desktop/learn/pandas_learn/venv/lib/python3.13/site-packages/pandas/io/excel/_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)    539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)    550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File ~/Desktop/learn/pandas_learn/venv/lib/python3.13/site-packages/pandas/compat/_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %% [markdown]
# Summary of the dataframe information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   first_name     1000 non-null   object
#  2   last_name      1000 non-null   object
#  3   email          878 non-null    object
#  4   gender         957 non-null    object
#  5   street_num     738 non-null    float64
#  6   street_name    963 non-null    object
#  7   street_suffix  963 non-null    object
#  8   city           921 non-null    object
#  9   state          920 non-null    object
#  10  postcode       843 non-null    float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 86.1+ KB

# %% [markdown]
# Add a new column named as 'Country' and the value inside that is 'USA' in the above dataframe.

# %%
data['Country'] = 'USA'

# %%
data.head()
# Out:
#    id first_name   last_name                      email  gender  street_num  \
# 0   1     Romain   Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2   3      Bambi     Westrip     bwestrip2@symantec.com  Female      4057.0
# 3   4     Roarke  Pankettman     rpankettman3@wiley.com    Male        74.0
# 4   5    Mikaela    Althorpe           malthorpe4@51.la     NaN         NaN
#
#   street_name street_suffix         city       state  postcode Country
# 0   Trailsway          Road    San Diego  California   92127.0     USA
# 1         NaN           NaN      El Paso       Texas       NaN     USA
# 2    Arkansas        Circle  San Antonio       Texas   78220.0     USA
# 3        Debs         Point      Memphis   Tennessee   38150.0     USA
# 4         2nd         Drive          NaN         NaN   83732.0     USA

# %% [markdown]
# Task 1: I want to place the 'country' column after the 'city' column.

# %%
membership_status = ['Gold', 'Silver', 'Bronze']
data['membership_status'] = membership_status
data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-e757600fbdcb> in <cell line: 0>()
#       1 membership_status = ['Gold', 'Silver', 'Bronze']
# ----> 2 data['membership_status'] = membership_status
#       3 data.head()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
#    4313     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
#    4526         if (
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    5264
#    5265         if is_list_like(value):
# -> 5266             com.require_length_match(value, self.index)
#    5267         arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268         if (
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     571     """
#     572     if len(data) != len(index):
# --> 573         raise ValueError(
#     574             "Length of values "
#     575             f"({len(data)}) "
#
# ValueError: Length of values (3) does not match length of index (1000)

# %% [markdown]
# Create a new column 'full_name' which is composed of first_name and the last_name.

# %%
data['full_name'] = data['first_name'] + ' ' + data['last_name']
data.head()
# Out:
#    id first_name   last_name                      email  gender  street_num  \
# 0   1     Romain   Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2   3      Bambi     Westrip     bwestrip2@symantec.com  Female      4057.0
# 3   4     Roarke  Pankettman     rpankettman3@wiley.com    Male        74.0
# 4   5    Mikaela    Althorpe           malthorpe4@51.la     NaN         NaN
#
#   street_name street_suffix         city       state  postcode Country  \
# 0   Trailsway          Road    San Diego  California   92127.0     USA
# 1         NaN           NaN      El Paso       Texas       NaN     USA
# 2    Arkansas        Circle  San Antonio       Texas   78220.0     USA
# 3        Debs         Point      Memphis   Tennessee   38150.0     USA
# 4         2nd         Drive          NaN         NaN   83732.0     USA
#
#            full_name
# 0   Romain Southcott
# 1   Cosimo Molyneaux
# 2      Bambi Westrip
# 3  Roarke Pankettman
# 4   Mikaela Althorpe

# %% [markdown]
# Access the rows in a given dataframe: .loc() vs .iloc()

# %%
dataframe_demo = {
    'Name': ['Akash', 'Amir', 'Abhishek', 'Nehal', 'Abhijeet'],
    'Age': [23, 34, 25, 27, 36],
    'City': ['Delhi', 'Bengaluru', 'Haryana', 'Noida', 'Pune']
}

dataframe_demo = pd.DataFrame(dataframe_demo, index=['a', 'b', 'c', 'd', 'e'])
dataframe_demo
# Out:
#        Name  Age       City
# a     Akash   23      Delhi
# b      Amir   34  Bengaluru
# c  Abhishek   25    Haryana
# d     Nehal   27      Noida
# e  Abhijeet   36       Pune

# %%
dataframe_demo.loc['b']
# Out:
# Name         Amir
# Age            34
# City    Bengaluru
# Name: b, dtype: object

# %%
dataframe_demo.loc['b':'d']
# Out:
#        Name  Age       City
# b      Amir   34  Bengaluru
# c  Abhishek   25    Haryana
# d     Nehal   27      Noida

# %%
dataframe_demo.iloc[1]
# Out:
# Name         Amir
# Age            34
# City    Bengaluru
# Name: b, dtype: object

# %%
dataframe_demo.iloc[1:4]
# Out:
#        Name  Age       City
# b      Amir   34  Bengaluru
# c  Abhishek   25    Haryana
# d     Nehal   27      Noida

# %%
dataframe_demo_v1 = {
    'Name': ['Akash', 'Amir', 'Abhishek', 'Nehal', 'Abhijeet'],
    'Age': [23, 34, 25, 27, 36],
    'City': ['Delhi', 'Bengaluru', 'Haryana', 'Noida', 'Pune']
}

dataframe_demo_v1 = pd.DataFrame(dataframe_demo_v1)
dataframe_demo_v1
# Out:
#        Name  Age       City
# 0     Akash   23      Delhi
# 1      Amir   34  Bengaluru
# 2  Abhishek   25    Haryana
# 3     Nehal   27      Noida
# 4  Abhijeet   36       Pune

# %%
dataframe_demo_v1.loc[0]
# Out:
# Name    Akash
# Age        23
# City    Delhi
# Name: 0, dtype: object

# %%
dataframe_demo_v1.iloc[0]
# Out:
# Name    Akash
# Age        23
# City    Delhi
# Name: 0, dtype: object

# %%
data.head()
# Out:
#    id first_name   last_name                      email  gender  street_num  \
# 0   1     Romain   Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2   3      Bambi     Westrip     bwestrip2@symantec.com  Female      4057.0
# 3   4     Roarke  Pankettman     rpankettman3@wiley.com    Male        74.0
# 4   5    Mikaela    Althorpe           malthorpe4@51.la     NaN         NaN
#
#   street_name street_suffix         city       state  postcode Country  \
# 0   Trailsway          Road    San Diego  California   92127.0     USA
# 1         NaN           NaN      El Paso       Texas       NaN     USA
# 2    Arkansas        Circle  San Antonio       Texas   78220.0     USA
# 3        Debs         Point      Memphis   Tennessee   38150.0     USA
# 4         2nd         Drive          NaN         NaN   83732.0     USA
#
#            full_name
# 0   Romain Southcott
# 1   Cosimo Molyneaux
# 2      Bambi Westrip
# 3  Roarke Pankettman
# 4   Mikaela Althorpe

# %%
data.shape
# Out:
# (1000, 13)

# %% [markdown]
# Access the details of the id's of the customers from 500 to 504.

# %%
data.loc[500:504]
# Out:
#       id first_name last_name                       email gender  street_num  \
# 500  501     Elliot  Polycote  epolycotedw@infoseek.co.jp   Male         NaN
# 501  502   Shirline    Halpin     shalpindx@moonfruit.com    NaN     76640.0
# 502  503      Darcy  Cruddace                         NaN    NaN         NaN
# 503  504    Toiboid   Bentzen     tbentzendz@freewebs.com   Male       913.0
# 504  505      Paxon    Corris       pcorrise0@behance.net   Male      8362.0
#
#     street_name street_suffix          city        state  postcode Country  \
# 500    Prentice         Drive      Hartford  Connecticut       NaN     USA
# 501       Buell        Circle        Dallas        Texas   75216.0     USA
# 502   Ridgeview         Court         Utica     New York   13505.0     USA
# 503         2nd         Trail  White Plains     New York   10606.0     USA
# 504       Eliot           Way    Des Moines         Iowa   50362.0     USA
#
#            full_name
# 500  Elliot Polycote
# 501  Shirline Halpin
# 502   Darcy Cruddace
# 503  Toiboid Bentzen
# 504     Paxon Corris

# %%
data.iloc[500:504]
# Out:
#       id first_name last_name                       email gender  street_num  \
# 500  501     Elliot  Polycote  epolycotedw@infoseek.co.jp   Male         NaN
# 501  502   Shirline    Halpin     shalpindx@moonfruit.com    NaN     76640.0
# 502  503      Darcy  Cruddace                         NaN    NaN         NaN
# 503  504    Toiboid   Bentzen     tbentzendz@freewebs.com   Male       913.0
#
#     street_name street_suffix          city        state  postcode Country  \
# 500    Prentice         Drive      Hartford  Connecticut       NaN     USA
# 501       Buell        Circle        Dallas        Texas   75216.0     USA
# 502   Ridgeview         Court         Utica     New York   13505.0     USA
# 503         2nd         Trail  White Plains     New York   10606.0     USA
#
#            full_name
# 500  Elliot Polycote
# 501  Shirline Halpin
# 502   Darcy Cruddace
# 503  Toiboid Bentzen

# %%
data[(data['id'] >= 500) & (data['id'] <= 504)]
# Out:
#       id first_name last_name                       email  gender  street_num  \
# 499  500   Carolann   Balcock        cbalcockdv@alexa.com  Female         NaN
# 500  501     Elliot  Polycote  epolycotedw@infoseek.co.jp    Male         NaN
# 501  502   Shirline    Halpin     shalpindx@moonfruit.com     NaN     76640.0
# 502  503      Darcy  Cruddace                         NaN     NaN         NaN
# 503  504    Toiboid   Bentzen     tbentzendz@freewebs.com    Male       913.0
#
#       street_name street_suffix          city        state  postcode Country  \
# 499  Stone Corner          Pass       El Paso        Texas   79916.0     USA
# 500      Prentice         Drive      Hartford  Connecticut       NaN     USA
# 501         Buell        Circle        Dallas        Texas   75216.0     USA
# 502     Ridgeview         Court         Utica     New York   13505.0     USA
# 503           2nd         Trail  White Plains     New York   10606.0     USA
#
#             full_name
# 499  Carolann Balcock
# 500   Elliot Polycote
# 501   Shirline Halpin
# 502    Darcy Cruddace
# 503   Toiboid Bentzen

# %%
data[500:504]
# Out:
#       id first_name last_name                       email gender  street_num  \
# 500  501     Elliot  Polycote  epolycotedw@infoseek.co.jp   Male         NaN
# 501  502   Shirline    Halpin     shalpindx@moonfruit.com    NaN     76640.0
# 502  503      Darcy  Cruddace                         NaN    NaN         NaN
# 503  504    Toiboid   Bentzen     tbentzendz@freewebs.com   Male       913.0
#
#     street_name street_suffix          city        state  postcode Country  \
# 500    Prentice         Drive      Hartford  Connecticut       NaN     USA
# 501       Buell        Circle        Dallas        Texas   75216.0     USA
# 502   Ridgeview         Court         Utica     New York   13505.0     USA
# 503         2nd         Trail  White Plains     New York   10606.0     USA
#
#            full_name
# 500  Elliot Polycote
# 501  Shirline Halpin
# 502   Darcy Cruddace
# 503  Toiboid Bentzen

# %%
data.drop(columns=['Country'], inplace=True)
data.head()
# Out:
#    id first_name   last_name                      email  gender  street_num  \
# 0   1     Romain   Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2   3      Bambi     Westrip     bwestrip2@symantec.com  Female      4057.0
# 3   4     Roarke  Pankettman     rpankettman3@wiley.com    Male        74.0
# 4   5    Mikaela    Althorpe           malthorpe4@51.la     NaN         NaN
#
#   street_name street_suffix         city       state  postcode  \
# 0   Trailsway          Road    San Diego  California   92127.0
# 1         NaN           NaN      El Paso       Texas       NaN
# 2    Arkansas        Circle  San Antonio       Texas   78220.0
# 3        Debs         Point      Memphis   Tennessee   38150.0
# 4         2nd         Drive          NaN         NaN   83732.0
#
#            full_name
# 0   Romain Southcott
# 1   Cosimo Molyneaux
# 2      Bambi Westrip
# 3  Roarke Pankettman
# 4   Mikaela Althorpe

# %% [markdown]
# Rename the row index with the custom index.
#
# '0' - 'firstCustomer'
#
# '1' - 'secondCustomer'

# %%
rename_dict = {
    0: 'firstCustomer',
    1: 'secondCustomer'
}

data.rename(index=rename_dict, inplace=True)
data.head()
# Out:
#                 id first_name   last_name                      email  gender  \
# firstCustomer    1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# secondCustomer   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2                3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3                4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4                5    Mikaela    Althorpe           malthorpe4@51.la     NaN
#
#                 street_num street_name street_suffix         city       state  \
# firstCustomer          1.0   Trailsway          Road    San Diego  California
# secondCustomer         NaN         NaN           NaN      El Paso       Texas
# 2                   4057.0    Arkansas        Circle  San Antonio       Texas
# 3                     74.0        Debs         Point      Memphis   Tennessee
# 4                      NaN         2nd         Drive          NaN         NaN
#
#                 postcode          full_name
# firstCustomer    92127.0   Romain Southcott
# secondCustomer       NaN   Cosimo Molyneaux
# 2                78220.0      Bambi Westrip
# 3                38150.0  Roarke Pankettman
# 4                83732.0   Mikaela Althorpe

# %% [markdown]
# Task 2: Can you rename the columns of street_num with the street_number and street_name with the street_address.

# %% [markdown]
# For non customised index iloc = loc else they are different.

# %%
data.loc['firstCustomer':'secondCustomer']
# Out:
#                 id first_name  last_name                      email gender  \
# firstCustomer    1     Romain  Southcott  rsouthcott0@clickbank.net   Male
# secondCustomer   2     Cosimo  Molyneaux      cmolyneaux1@wiley.com   Male
#
#                 street_num street_name street_suffix       city       state  \
# firstCustomer          1.0   Trailsway          Road  San Diego  California
# secondCustomer         NaN         NaN           NaN    El Paso       Texas
#
#                 postcode         full_name
# firstCustomer    92127.0  Romain Southcott
# secondCustomer       NaN  Cosimo Molyneaux

# %%
data.iloc[0:2]
# Out:
#                 id first_name  last_name                      email gender  \
# firstCustomer    1     Romain  Southcott  rsouthcott0@clickbank.net   Male
# secondCustomer   2     Cosimo  Molyneaux      cmolyneaux1@wiley.com   Male
#
#                 street_num street_name street_suffix       city       state  \
# firstCustomer          1.0   Trailsway          Road  San Diego  California
# secondCustomer         NaN         NaN           NaN    El Paso       Texas
#
#                 postcode         full_name
# firstCustomer    92127.0  Romain Southcott
# secondCustomer       NaN  Cosimo Molyneaux

# %% [markdown]
# Finding the unique values

# %%
unique_gender = data['gender'].unique()
print(unique_gender)
# Out:
# ['Male' 'Female' nan]

# %% [markdown]
# Count of the unique values in the given column in a dataframe.

# %% [markdown]
# Note: It will only return the non-null values as the count.

# %%
count_unique_gender = data['gender'].nunique()
print(count_unique_gender)
# Out:
# 2

# %%
data['gender'].value_counts()
# Out:
# gender
# Male      485
# Female    472
# Name: count, dtype: int64

# %%
data.dtypes
# Out:
# id                 int64
# first_name        object
# last_name         object
# email             object
# gender            object
# street_num       float64
# street_name       object
# street_suffix     object
# city              object
# state             object
# postcode         float64
# full_name         object
# dtype: object

# %%
data_purchases = pd.read_excel('../dataset/purchases.xlsx')
data_purchases.head()
# Out:
#    Unnamed: 0  id           purch_date  customer_num  product_num  amount  \
# 0           0   1  2019-01-03 00:00:00           823           27      12
# 1           1   2  2019-01-03 00:00:00           606           28      14
# 2           2   3  2019-01-03 00:00:00           955            9      17
# 3           3   4  2019-01-03 00:00:00           577           19       3
# 4           4   5  2019-01-03 00:00:00           429            8      18
#
#       paid
# 0  $568.92
# 1  $395.36
# 2  $510.17
# 3   $68.49
# 4  $759.42

# %%
data_purchases.dtypes
# Out:
# Unnamed: 0       int64
# id               int64
# purch_date      object
# customer_num     int64
# product_num      int64
# amount           int64
# paid            object
# dtype: object

# %%
data_purchases.drop(columns=['Unnamed: 0'], inplace=True)
data_purchases.head()
# Out:
#    id           purch_date  customer_num  product_num  amount     paid
# 0   1  2019-01-03 00:00:00           823           27      12  $568.92
# 1   2  2019-01-03 00:00:00           606           28      14  $395.36
# 2   3  2019-01-03 00:00:00           955            9      17  $510.17
# 3   4  2019-01-03 00:00:00           577           19       3   $68.49
# 4   5  2019-01-03 00:00:00           429            8      18  $759.42

# %% [markdown]
# Handle the data types of the column in an appropriate manner.

# %% [markdown]
# purch_data -> datetime

# %%
data_purchases['purch_date'] = pd.to_datetime(data_purchases['purch_date'])
data_purchases.dtypes
# Out:
# id                       int64
# purch_date      datetime64[ns]
# customer_num             int64
# product_num              int64
# amount                   int64
# paid                    object
# dtype: object

# %% [markdown]
# id -> object

# %%
data_purchases['id'] = data_purchases['id'].astype(object)
data_purchases.dtypes
# Out:
# id                      object
# purch_date      datetime64[ns]
# customer_num             int64
# product_num              int64
# amount                   int64
# paid                    object
# dtype: object

# %% [markdown]
# paid -> float

# %%
## paid -> data preprocess and then only we can do the type-conversion

## the below code will simply remove the $ and , from the paid column using a regular expression
data_purchases['paid'] = data_purchases['paid'].str.replace('[\$,]', '', regex=True)
data_purchases.head()
# Out:
#   id purch_date  customer_num  product_num  amount    paid
# 0  1 2019-01-03           823           27      12  568.92
# 1  2 2019-01-03           606           28      14  395.36
# 2  3 2019-01-03           955            9      17  510.17
# 3  4 2019-01-03           577           19       3   68.49
# 4  5 2019-01-03           429            8      18  759.42

# %%
data_purchases.dtypes
# Out:
# id                      object
# purch_date      datetime64[ns]
# customer_num             int64
# product_num              int64
# amount                   int64
# paid                    object
# dtype: object

# %%
data_purchases['paid'] = data_purchases['paid'].astype(float)
data_purchases.dtypes
# Out:
# id                      object
# purch_date      datetime64[ns]
# customer_num             int64
# product_num              int64
# amount                   int64
# paid                   float64
# dtype: object

# %%
data_products = pd.read_excel('../dataset/products.xlsx')
data_products.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Desktop/learn/pandas_learn/venv/lib/python3.13/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /usr/local/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data_products = pd.read_excel('../dataset/products.xlsx')
#       2 data_products.head()
#
# File ~/Desktop/learn/pandas_learn/venv/lib/python3.13/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~/Desktop/learn/pandas_learn/venv/lib/python3.13/site-packages/pandas/io/excel/_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File ~/Desktop/learn/pandas_learn/venv/lib/python3.13/site-packages/pandas/io/excel/_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)    539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)    550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File ~/Desktop/learn/pandas_learn/venv/lib/python3.13/site-packages/pandas/compat/_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
data_products.dtypes
# Out:
# Unnamed: 0     int64
# id             int64
# product       object
# cost          object
# company       object
# dtype: object

# %%
data_products.drop(columns=['Unnamed: 0'], inplace=True)

# %%
data_products.dtypes
# Out:
# id          int64
# product    object
# cost       object
# company    object
# dtype: object

# %%
data_products['cost'] = data_products['cost'].str.replace('[\$, ]', '', regex=True).astype(float)
data_products.dtypes
# Out:
# id           int64
# product     object
# cost       float64
# company     object
# dtype: object

# %%
data_products['id'] = data_products['id'].astype(object)
data_products.dtypes
# Out:
# id          object
# product     object
# cost       float64
# company     object
# dtype: object

# %%
data_purchases.shape
# Out:
# (6000, 6)

# %%
data_products.shape
# Out:
# (60, 4)

# %%
data.shape
# Out:
# (1000, 12)

# %% [markdown]
# SQL Union

# %% [markdown]
# pd.concat -> to manipulation and combine multiple dataframes in pandas.

# %%
combined_df = pd.concat([data, data_purchases, data_products]) ## axis = 0[default] row-wise concatenation, axis = 1 -> column wise concatenation
combined_df
# Out:
#                 id first_name   last_name                      email  gender  \
# firstCustomer    1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# secondCustomer   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2                3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3                4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4                5    Mikaela    Althorpe           malthorpe4@51.la     NaN
# ...             ..        ...         ...                        ...     ...
# 55              56        NaN         NaN                        NaN     NaN
# 56              57        NaN         NaN                        NaN     NaN
# 57              58        NaN         NaN                        NaN     NaN
# 58              59        NaN         NaN                        NaN     NaN
# 59              60        NaN         NaN                        NaN     NaN
#
#                 street_num street_name street_suffix         city       state  \
# firstCustomer          1.0   Trailsway          Road    San Diego  California
# secondCustomer         NaN         NaN           NaN      El Paso       Texas
# 2                   4057.0    Arkansas        Circle  San Antonio       Texas
# 3                     74.0        Debs         Point      Memphis   Tennessee
# 4                      NaN         2nd         Drive          NaN         NaN
# ...                    ...         ...           ...          ...         ...
# 55                     NaN         NaN           NaN          NaN         NaN
# 56                     NaN         NaN           NaN          NaN         NaN
# 57                     NaN         NaN           NaN          NaN         NaN
# 58                     NaN         NaN           NaN          NaN         NaN
# 59                     NaN         NaN           NaN          NaN         NaN
#
#                 postcode          full_name purch_date  customer_num  \
# firstCustomer    92127.0   Romain Southcott        NaT           NaN
# secondCustomer       NaN   Cosimo Molyneaux        NaT           NaN
# 2                78220.0      Bambi Westrip        NaT           NaN
# 3                38150.0  Roarke Pankettman        NaT           NaN
# 4                83732.0   Mikaela Althorpe        NaT           NaN
# ...                  ...                ...        ...           ...
# 55                   NaN                NaN        NaT           NaN
# 56                   NaN                NaN        NaT           NaN
# 57                   NaN                NaN        NaT           NaN
# 58                   NaN                NaN        NaT           NaN
# 59                   NaN                NaN        NaT           NaN
#
#                 product_num  amount  paid                        product  \
# firstCustomer           NaN     NaN   NaN                            NaN
# secondCustomer          NaN     NaN   NaN                            NaN
# 2                       NaN     NaN   NaN                            NaN
# 3                       NaN     NaN   NaN                            NaN
# 4                       NaN     NaN   NaN                            NaN
# ...                     ...     ...   ...                            ...
# 55                      NaN     NaN   NaN                  Peach - Fresh
# 56                      NaN     NaN   NaN            Muffin Hinge - 211n
# 57                      NaN     NaN   NaN             Bar Bran Honey Nut
# 58                      NaN     NaN   NaN  Nut - Almond, Blanched, Whole
# 59                      NaN     NaN   NaN       Table Cloth 90x90 Colour
#
#                  cost   company
# firstCustomer     NaN       NaN
# secondCustomer    NaN       NaN
# 2                 NaN       NaN
# 3                 NaN       NaN
# 4                 NaN       NaN
# ...               ...       ...
# 55              20.53     Zazio
# 56              68.63  Fanoodle
# 57              73.05    Yakijo
# 58              74.28     Eazzy
# 59              41.22     Quinu
#
# [7060 rows x 20 columns]

# %% [markdown]
# SQL Joins => Inner, Left, Right, Outer

# %% [markdown]
# pd.merge

# %%
data.head()
# Out:
#                 id first_name   last_name                      email  gender  \
# firstCustomer    1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# secondCustomer   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2                3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3                4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4                5    Mikaela    Althorpe           malthorpe4@51.la     NaN
#
#                 street_num street_name street_suffix         city       state  \
# firstCustomer          1.0   Trailsway          Road    San Diego  California
# secondCustomer         NaN         NaN           NaN      El Paso       Texas
# 2                   4057.0    Arkansas        Circle  San Antonio       Texas
# 3                     74.0        Debs         Point      Memphis   Tennessee
# 4                      NaN         2nd         Drive          NaN         NaN
#
#                 postcode          full_name
# firstCustomer    92127.0   Romain Southcott
# secondCustomer       NaN   Cosimo Molyneaux
# 2                78220.0      Bambi Westrip
# 3                38150.0  Roarke Pankettman
# 4                83732.0   Mikaela Althorpe

# %%
data_purchases.head()
# Out:
#   id purch_date  customer_num  product_num  amount    paid
# 0  1 2019-01-03           823           27      12  568.92
# 1  2 2019-01-03           606           28      14  395.36
# 2  3 2019-01-03           955            9      17  510.17
# 3  4 2019-01-03           577           19       3   68.49
# 4  5 2019-01-03           429            8      18  759.42

# %%
merged_df = pd.merge(data, data_purchases, on='id', how='inner')
merged_df
# Out:
#        id first_name    last_name                           email  gender  \
# 0       1     Romain    Southcott       rsouthcott0@clickbank.net    Male
# 1       2     Cosimo    Molyneaux           cmolyneaux1@wiley.com    Male
# 2       3      Bambi      Westrip          bwestrip2@symantec.com  Female
# 3       4     Roarke   Pankettman          rpankettman3@wiley.com    Male
# 4       5    Mikaela     Althorpe                malthorpe4@51.la     NaN
# ..    ...        ...          ...                             ...     ...
# 995   996    Merrili        Alman            malmanrn@cornell.edu  Female
# 996   997    Winonah       Heckle               whecklero@fc2.com  Female
# 997   998      Tobit         Birt                             NaN    Male
# 998   999     Issiah  Standbrooke  istandbrookerq@yellowpages.com    Male
# 999  1000     Elmore       Malpas                             NaN    Male
#
#      street_num street_name street_suffix          city         state  \
# 0           1.0   Trailsway          Road     San Diego    California
# 1           NaN         NaN           NaN       El Paso         Texas
# 2        4057.0    Arkansas        Circle   San Antonio         Texas
# 3          74.0        Debs         Point       Memphis     Tennessee
# 4           NaN         2nd         Drive           NaN           NaN
# ..          ...         ...           ...           ...           ...
# 995         0.0    Thompson           Way       Reading  Pennsylvania
# 996       701.0     Rowland          Hill  Indianapolis       Indiana
# 997         2.0       Basil          Road     Waterbury   Connecticut
# 998         NaN     Kenwood         Drive      Savannah       Georgia
# 999       205.0     Farwell          Park       Atlanta       Georgia
#
#      postcode           full_name purch_date  customer_num  product_num  \
# 0     92127.0    Romain Southcott 2019-01-03           823           27
# 1         NaN    Cosimo Molyneaux 2019-01-03           606           28
# 2     78220.0       Bambi Westrip 2019-01-03           955            9
# 3     38150.0   Roarke Pankettman 2019-01-03           577           19
# 4     83732.0    Mikaela Althorpe 2019-01-03           429            8
# ..        ...                 ...        ...           ...          ...
# 995   19610.0       Merrili Alman 2019-06-04           198           20
# 996   46278.0      Winonah Heckle 2019-06-04            96           27
# 997    6721.0          Tobit Birt 2019-06-04           181            7
# 998   31405.0  Issiah Standbrooke 2019-06-04           951           54
# 999   30386.0       Elmore Malpas 2019-06-04           435           20
#
#      amount     paid
# 0        12   568.92
# 1        14   395.36
# 2        17   510.17
# 3         3    68.49
# 4        18   759.42
# ..      ...      ...
# 995       7   609.35
# 996      14   663.74
# 997       2    27.66
# 998       4    87.68
# 999      18  1143.90
#
# [1000 rows x 17 columns]

# %%
merged_df_right = pd.merge(data, data_purchases, on='id', how='right')
merged_df_right
# Out:
#         id first_name   last_name                      email  gender  \
# 0        1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# 1        2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2        3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3        4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4        5    Mikaela    Althorpe           malthorpe4@51.la     NaN
# ...    ...        ...         ...                        ...     ...
# 5995  5996        NaN         NaN                        NaN     NaN
# 5996  5997        NaN         NaN                        NaN     NaN
# 5997  5998        NaN         NaN                        NaN     NaN
# 5998  5999        NaN         NaN                        NaN     NaN
# 5999  6000        NaN         NaN                        NaN     NaN
#
#       street_num street_name street_suffix         city       state  postcode  \
# 0            1.0   Trailsway          Road    San Diego  California   92127.0
# 1            NaN         NaN           NaN      El Paso       Texas       NaN
# 2         4057.0    Arkansas        Circle  San Antonio       Texas   78220.0
# 3           74.0        Debs         Point      Memphis   Tennessee   38150.0
# 4            NaN         2nd         Drive          NaN         NaN   83732.0
# ...          ...         ...           ...          ...         ...       ...
# 5995         NaN         NaN           NaN          NaN         NaN       NaN
# 5996         NaN         NaN           NaN          NaN         NaN       NaN
# 5997         NaN         NaN           NaN          NaN         NaN       NaN
# 5998         NaN         NaN           NaN          NaN         NaN       NaN
# 5999         NaN         NaN           NaN          NaN         NaN       NaN
#
#               full_name purch_date  customer_num  product_num  amount    paid
# 0      Romain Southcott 2019-01-03           823           27      12  568.92
# 1      Cosimo Molyneaux 2019-01-03           606           28      14  395.36
# 2         Bambi Westrip 2019-01-03           955            9      17  510.17
# 3     Roarke Pankettman 2019-01-03           577           19       3   68.49
# 4      Mikaela Althorpe 2019-01-03           429            8      18  759.42
# ...                 ...        ...           ...          ...     ...     ...
# 5995                NaN 2019-06-20           893           33       5  411.10
# 5996                NaN 2019-06-20           566           23      11  178.97
# 5997                NaN 2019-06-20           114           19       9  205.47
# 5998                NaN 2019-06-20           404           11      20  429.40
# 5999                NaN 2019-06-20            88           57       4  274.52
#
# [6000 rows x 17 columns]

# %%
data1_customers = pd.DataFrame({
    'id': [1, 2, 3],
    'name': ['alice', 'bob', 'charlie'],
    'product':['book', 'pen', 'notebook']
})


data2_purchases = pd.DataFrame({
    'id': [2, 3, 4],
    'product': ['pen', 'notebook', 'pen'],
    'amount' : [5, 10, 15]
})

merged_df = pd.merge(data1_customers, data2_purchases, on='id', how='left', suffixes=('_cust', '_pur'))
merged_df
# Out:
#    id     name product_cust product_pur  amount
# 0   1    alice         book         NaN     NaN
# 1   2      bob          pen         pen     5.0
# 2   3  charlie     notebook    notebook    10.0

# %% [markdown]
# Task 3: Difference between pd.concat, pd.merge and pd.join

# %% [markdown]
# Missing Values

# %%
data.isnull().sum()
# Out:
# id                 0
# first_name         0
# last_name          0
# email            122
# gender            43
# street_num       262
# street_name       37
# street_suffix     37
# city              79
# state             80
# postcode         157
# full_name          0
# dtype: int64

# %%
data_purchases.isnull().sum()
# Out:
# id              0
# purch_date      0
# customer_num    0
# product_num     0
# amount          0
# paid            0
# dtype: int64

# %%
data_products.isnull().sum()
# Out:
# id         0
# product    0
# cost       0
# company    5
# dtype: int64

# %% [markdown]
# Drop all the missing values.

# %%
customers_copy = data.copy()
customers_copy.head()
# Out:
#                 id first_name   last_name                      email  gender  \
# firstCustomer    1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# secondCustomer   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2                3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3                4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4                5    Mikaela    Althorpe           malthorpe4@51.la     NaN
#
#                 street_num street_name street_suffix         city       state  \
# firstCustomer          1.0   Trailsway          Road    San Diego  California
# secondCustomer         NaN         NaN           NaN      El Paso       Texas
# 2                   4057.0    Arkansas        Circle  San Antonio       Texas
# 3                     74.0        Debs         Point      Memphis   Tennessee
# 4                      NaN         2nd         Drive          NaN         NaN
#
#                 postcode          full_name
# firstCustomer    92127.0   Romain Southcott
# secondCustomer       NaN   Cosimo Molyneaux
# 2                78220.0      Bambi Westrip
# 3                38150.0  Roarke Pankettman
# 4                83732.0   Mikaela Althorpe

# %% [markdown]
# Strategy 1: dropna() -> only when you have a very small proportion of the missing data. Otherwise, please avoid this strategy because that leads to the loss of information.

# %%
customers_copy = customers_copy.dropna()
customers_copy.isnull().sum()
# Out:
# id               0
# first_name       0
# last_name        0
# email            0
# gender           0
# street_num       0
# street_name      0
# street_suffix    0
# city             0
# state            0
# postcode         0
# full_name        0
# dtype: int64

# %%
customers_copy.shape
# Out:
# (418, 12)

# %% [markdown]
# Strategy 2: Data Imputation

# %% [markdown]
# Imputation -> With the measures of central tendency [mean, median, mode]

# %% [markdown]
# How can we deal with the categorical data -> mode

# %% [markdown]
# Suppose i have 40% null data and remaining data have 50% male and 50% female and if use male to fill remaining null values as it is first occuring will that be an inaccuracy?

# %%
mode_gender = data['gender'].mode()[0]
print(mode_gender)
# Out:
# Male

# %%
data['gender'].fillna(mode_gender, inplace=True)
data.isnull().sum()
# Out:
# <ipython-input-48-1798c3f4fc8a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['gender'].fillna(mode_gender, inplace=True)
# id                 0
# first_name         0
# last_name          0
# email            122
# gender             0
# street_num       262
# street_name       37
# street_suffix     37
# city              79
# state             80
# postcode         157
# full_name          0
# dtype: int64

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.head(20)
# Out:
#                 id  first_name      last_name                        email  \
# firstCustomer    1      Romain      Southcott    rsouthcott0@clickbank.net
# secondCustomer   2      Cosimo      Molyneaux        cmolyneaux1@wiley.com
# 2                3       Bambi        Westrip       bwestrip2@symantec.com
# 3                4      Roarke     Pankettman       rpankettman3@wiley.com
# 4                5     Mikaela       Althorpe             malthorpe4@51.la
# 5                6   Magdalena         Cullip             mcullip5@tiny.cc
# 6                7    Marietta         Heball            mheball6@blog.com
# 7                8        Tine      McSperrin  tmcsperrin7@statcounter.com
# 8                9  Enrichetta     de Villier         edevillier8@ox.ac.uk
# 9               10        Sari        Poulden           spoulden9@xing.com
# 10              11      Natale        Martina      nmartinaa@wordpress.com
# 11              12        Noni     Norrington    nnorringtonb@netvibes.com
# 12              13       Mikol        MacWhan          mmacwhanc@patch.com
# 13              14        Deny        Thraves            dthravesd@ibm.com
# 14              15        Fara       Petegrew          fpetegrewe@ebay.com
# 15              16       Jodie  De Cristoforo       jdecristoforof@mac.com
# 16              17        Tobi        Dewicke      tdewickeg@hostgator.com
# 17              18    Reinhold      Woolforde           rwoolfordeh@cbc.ca
# 18              19      Fredek          Foley              ffoleyi@bbb.org
# 19              20      Rubina       Hustings     rhustingsj@wikimedia.org
#
#                 gender  street_num   street_name street_suffix           city  \
# firstCustomer     Male         1.0     Trailsway          Road      San Diego
# secondCustomer    Male         NaN           NaN           NaN        El Paso
# 2               Female      4057.0      Arkansas        Circle    San Antonio
# 3                 Male        74.0          Debs         Point        Memphis
# 4                 Male         NaN           2nd         Drive            NaN
# 5               Female      9190.0       Packers         Drive      Baltimore
# 6               Female        12.0       Mallory        Center   Carol Stream
# 7                 Male       530.0          Erie         Plaza    Kansas City
# 8               Female       745.0      Annamark        Street      Fairbanks
# 9               Female         2.0          Pond          Hill    New Orleans
# 10                Male       221.0      Sauthoff          Pass      Bradenton
# 11              Female         5.0           NaN           NaN      Baltimore
# 12                Male         9.0   Eagle Crest        Center          Bronx
# 13              Female     71865.0   Valley Edge         Place     Washington
# 14              Female         NaN     Claremont         Place    Los Angeles
# 15                Male     50948.0       Rowland         Alley     Charleston
# 16              Female      6817.0          Orin      Junction     San Rafael
# 17                Male         NaN  Northwestern           Way       Amarillo
# 18                Male         8.0      Ridgeway          Park  Silver Spring
# 19              Female       249.0         Esker          Hill    San Antonio
#
#                                state  postcode              full_name
# firstCustomer             California   92127.0       Romain Southcott
# secondCustomer                 Texas       NaN       Cosimo Molyneaux
# 2                              Texas   78220.0          Bambi Westrip
# 3                          Tennessee   38150.0      Roarke Pankettman
# 4                                NaN   83732.0       Mikaela Althorpe
# 5                           Maryland   21229.0       Magdalena Cullip
# 6                           Illinois   60351.0        Marietta Heball
# 7                           Missouri   64193.0         Tine McSperrin
# 8                             Alaska   99709.0  Enrichetta de Villier
# 9                          Louisiana       NaN           Sari Poulden
# 10                           Florida   34205.0         Natale Martina
# 11                          Maryland   21282.0        Noni Norrington
# 12                          New York   10469.0          Mikol MacWhan
# 13              District of Columbia   20456.0           Deny Thraves
# 14                        California   90005.0          Fara Petegrew
# 15                    South Carolina   29424.0    Jodie De Cristoforo
# 16                               NaN       NaN           Tobi Dewicke
# 17                             Texas   79118.0     Reinhold Woolforde
# 18                          Maryland   20910.0           Fredek Foley
# 19                             Texas   78210.0        Rubina Hustings

# %% [markdown]
# How can we deal with the numeric data -> ffill(), bfill(), mean(), median()

# %%
data.head(40)
# Out:
#                 id  first_name      last_name                        email  \
# firstCustomer    1      Romain      Southcott    rsouthcott0@clickbank.net
# secondCustomer   2      Cosimo      Molyneaux        cmolyneaux1@wiley.com
# 2                3       Bambi        Westrip       bwestrip2@symantec.com
# 3                4      Roarke     Pankettman       rpankettman3@wiley.com
# 4                5     Mikaela       Althorpe             malthorpe4@51.la
# 5                6   Magdalena         Cullip             mcullip5@tiny.cc
# 6                7    Marietta         Heball            mheball6@blog.com
# 7                8        Tine      McSperrin  tmcsperrin7@statcounter.com
# 8                9  Enrichetta     de Villier         edevillier8@ox.ac.uk
# 9               10        Sari        Poulden           spoulden9@xing.com
# 10              11      Natale        Martina      nmartinaa@wordpress.com
# 11              12        Noni     Norrington    nnorringtonb@netvibes.com
# 12              13       Mikol        MacWhan          mmacwhanc@patch.com
# 13              14        Deny        Thraves            dthravesd@ibm.com
# 14              15        Fara       Petegrew          fpetegrewe@ebay.com
# 15              16       Jodie  De Cristoforo       jdecristoforof@mac.com
# 16              17        Tobi        Dewicke      tdewickeg@hostgator.com
# 17              18    Reinhold      Woolforde           rwoolfordeh@cbc.ca
# 18              19      Fredek          Foley              ffoleyi@bbb.org
# 19              20      Rubina       Hustings     rhustingsj@wikimedia.org
# 20              21       Karim        Woosnam          kwoosnamk@ifeng.com
# 21              22     Woodrow          Fidoe  wfidoel@creativecommons.org
# 22              23     Loralie        Normand            lnormandm@usa.gov
# 23              24      Danita      Cleynaert      dcleynaertn@t-online.de
# 24              25      Tomlin      Massinger                          NaN
# 25              26    Franklin         Goodge        fgoodgep@mapquest.com
# 26              27     Harlene         Rameau     hrameauq@squarespace.com
# 27              28     Brander      Quinnelly    bquinnellyr@shinystat.com
# 28              29      Jeanna        Bruntje      jbruntjes@tuttocitta.it
# 29              30      Ardyth           Zack         azackt@wordpress.com
# 30              31       Steve      Pantridge                          NaN
# 31              32        Brit          Nouch            bnouchv@yahoo.com
# 32              33       Caril       Barnsley    cbarnsleyw@bravesites.com
# 33              34    Rosalynd        Dyerson       rdyersonx@geocities.jp
# 34              35      Griffy         Sonley      gsonleyy@deviantart.com
# 35              36      Ernest          Armal      earmalz@dailymail.co.uk
# 36              37     Elspeth         Mendus          emendus10@ocn.ne.jp
# 37              38     Clarita        Bussons   cbussons11@marketwatch.com
# 38              39   Stanislas         Hacaud                          NaN
# 39              40      Melvyn        Seifert   mseifert13@photobucket.com
#
#                 gender  street_num   street_name street_suffix           city  \
# firstCustomer     Male         1.0     Trailsway          Road      San Diego
# secondCustomer    Male         NaN           NaN           NaN        El Paso
# 2               Female      4057.0      Arkansas        Circle    San Antonio
# 3                 Male        74.0          Debs         Point        Memphis
# 4                 Male         NaN           2nd         Drive            NaN
# 5               Female      9190.0       Packers         Drive      Baltimore
# 6               Female        12.0       Mallory        Center   Carol Stream
# 7                 Male       530.0          Erie         Plaza    Kansas City
# 8               Female       745.0      Annamark        Street      Fairbanks
# 9               Female         2.0          Pond          Hill    New Orleans
# 10                Male       221.0      Sauthoff          Pass      Bradenton
# 11              Female         5.0           NaN           NaN      Baltimore
# 12                Male         9.0   Eagle Crest        Center          Bronx
# 13              Female     71865.0   Valley Edge         Place     Washington
# 14              Female         NaN     Claremont         Place    Los Angeles
# 15                Male     50948.0       Rowland         Alley     Charleston
# 16              Female      6817.0          Orin      Junction     San Rafael
# 17                Male         NaN  Northwestern           Way       Amarillo
# 18                Male         8.0      Ridgeway          Park  Silver Spring
# 19              Female       249.0         Esker          Hill    San Antonio
# 20                Male         NaN      Grayhawk         Place        Houston
# 21                Male         1.0       Artisan      Junction    Gainesville
# 22              Female         1.0     Transport       Terrace         Duluth
# 23              Female         NaN        Shopko        Center         Denton
# 24                Male         9.0      Victoria         Trail     Washington
# 25                Male     97670.0    Kensington        Center        Houston
# 26              Female      2352.0      American           Way        Seattle
# 27                Male       573.0      Dovetail        Center         Sparks
# 28              Female      9296.0       Hanover          Road     Fort Wayne
# 29              Female       437.0    Pierstorff           Way     Pittsburgh
# 30                Male      6124.0         Kropf        Street    Los Angeles
# 31              Female      2385.0        Blaine         Trail        Augusta
# 32              Female         NaN       Mallory           Way     Fort Wayne
# 33              Female         NaN          Cody         Court         Dallas
# 34                Male         1.0           NaN           NaN            NaN
# 35                Male         4.0         Susan        Center     Washington
# 36              Female       127.0   Mockingbird          Hill     Washington
# 37              Female      7444.0  Northwestern      Crossing        Lansing
# 38                Male        76.0  Summer Ridge         Place        Atlanta
# 39                Male         NaN   Park Meadow          Pass    San Antonio
#
#                                state  postcode              full_name
# firstCustomer             California   92127.0       Romain Southcott
# secondCustomer                 Texas       NaN       Cosimo Molyneaux
# 2                              Texas   78220.0          Bambi Westrip
# 3                          Tennessee   38150.0      Roarke Pankettman
# 4                                NaN   83732.0       Mikaela Althorpe
# 5                           Maryland   21229.0       Magdalena Cullip
# 6                           Illinois   60351.0        Marietta Heball
# 7                           Missouri   64193.0         Tine McSperrin
# 8                             Alaska   99709.0  Enrichetta de Villier
# 9                          Louisiana       NaN           Sari Poulden
# 10                           Florida   34205.0         Natale Martina
# 11                          Maryland   21282.0        Noni Norrington
# 12                          New York   10469.0          Mikol MacWhan
# 13              District of Columbia   20456.0           Deny Thraves
# 14                        California   90005.0          Fara Petegrew
# 15                    South Carolina   29424.0    Jodie De Cristoforo
# 16                               NaN       NaN           Tobi Dewicke
# 17                             Texas   79118.0     Reinhold Woolforde
# 18                          Maryland   20910.0           Fredek Foley
# 19                             Texas   78210.0        Rubina Hustings
# 20                             Texas       NaN          Karim Woosnam
# 21                               NaN       NaN          Woodrow Fidoe
# 22                               NaN   30195.0        Loralie Normand
# 23                             Texas   76205.0       Danita Cleynaert
# 24              District of Columbia   20409.0       Tomlin Massinger
# 25                             Texas   77240.0        Franklin Goodge
# 26                        Washington   98127.0         Harlene Rameau
# 27                            Nevada   89436.0      Brander Quinnelly
# 28                           Indiana   46814.0         Jeanna Bruntje
# 29                      Pennsylvania       NaN            Ardyth Zack
# 30                        California   90065.0        Steve Pantridge
# 31                           Georgia       NaN             Brit Nouch
# 32                           Indiana   46896.0         Caril Barnsley
# 33                             Texas   75226.0       Rosalynd Dyerson
# 34                          Virginia   22070.0          Griffy Sonley
# 35              District of Columbia   20231.0           Ernest Armal
# 36              District of Columbia       NaN         Elspeth Mendus
# 37                          Michigan   48912.0        Clarita Bussons
# 38                           Georgia   31119.0       Stanislas Hacaud
# 39                             Texas   78260.0         Melvyn Seifert

# %%
data['street_num'].fillna(method='ffill', inplace=True)
data.isnull().sum()
# Out:
# <ipython-input-52-c4ae133be938>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['street_num'].fillna(method='ffill', inplace=True)
# <ipython-input-52-c4ae133be938>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['street_num'].fillna(method='ffill', inplace=True)
# id                 0
# first_name         0
# last_name          0
# email            122
# gender             0
# street_num         0
# street_name       37
# street_suffix     37
# city              79
# state             80
# postcode         157
# full_name          0
# dtype: int64

# %%
data.head(40)
# Out:
#                 id  first_name      last_name                        email  \
# firstCustomer    1      Romain      Southcott    rsouthcott0@clickbank.net
# secondCustomer   2      Cosimo      Molyneaux        cmolyneaux1@wiley.com
# 2                3       Bambi        Westrip       bwestrip2@symantec.com
# 3                4      Roarke     Pankettman       rpankettman3@wiley.com
# 4                5     Mikaela       Althorpe             malthorpe4@51.la
# 5                6   Magdalena         Cullip             mcullip5@tiny.cc
# 6                7    Marietta         Heball            mheball6@blog.com
# 7                8        Tine      McSperrin  tmcsperrin7@statcounter.com
# 8                9  Enrichetta     de Villier         edevillier8@ox.ac.uk
# 9               10        Sari        Poulden           spoulden9@xing.com
# 10              11      Natale        Martina      nmartinaa@wordpress.com
# 11              12        Noni     Norrington    nnorringtonb@netvibes.com
# 12              13       Mikol        MacWhan          mmacwhanc@patch.com
# 13              14        Deny        Thraves            dthravesd@ibm.com
# 14              15        Fara       Petegrew          fpetegrewe@ebay.com
# 15              16       Jodie  De Cristoforo       jdecristoforof@mac.com
# 16              17        Tobi        Dewicke      tdewickeg@hostgator.com
# 17              18    Reinhold      Woolforde           rwoolfordeh@cbc.ca
# 18              19      Fredek          Foley              ffoleyi@bbb.org
# 19              20      Rubina       Hustings     rhustingsj@wikimedia.org
# 20              21       Karim        Woosnam          kwoosnamk@ifeng.com
# 21              22     Woodrow          Fidoe  wfidoel@creativecommons.org
# 22              23     Loralie        Normand            lnormandm@usa.gov
# 23              24      Danita      Cleynaert      dcleynaertn@t-online.de
# 24              25      Tomlin      Massinger                          NaN
# 25              26    Franklin         Goodge        fgoodgep@mapquest.com
# 26              27     Harlene         Rameau     hrameauq@squarespace.com
# 27              28     Brander      Quinnelly    bquinnellyr@shinystat.com
# 28              29      Jeanna        Bruntje      jbruntjes@tuttocitta.it
# 29              30      Ardyth           Zack         azackt@wordpress.com
# 30              31       Steve      Pantridge                          NaN
# 31              32        Brit          Nouch            bnouchv@yahoo.com
# 32              33       Caril       Barnsley    cbarnsleyw@bravesites.com
# 33              34    Rosalynd        Dyerson       rdyersonx@geocities.jp
# 34              35      Griffy         Sonley      gsonleyy@deviantart.com
# 35              36      Ernest          Armal      earmalz@dailymail.co.uk
# 36              37     Elspeth         Mendus          emendus10@ocn.ne.jp
# 37              38     Clarita        Bussons   cbussons11@marketwatch.com
# 38              39   Stanislas         Hacaud                          NaN
# 39              40      Melvyn        Seifert   mseifert13@photobucket.com
#
#                 gender  street_num   street_name street_suffix           city  \
# firstCustomer     Male         1.0     Trailsway          Road      San Diego
# secondCustomer    Male         1.0           NaN           NaN        El Paso
# 2               Female      4057.0      Arkansas        Circle    San Antonio
# 3                 Male        74.0          Debs         Point        Memphis
# 4                 Male        74.0           2nd         Drive            NaN
# 5               Female      9190.0       Packers         Drive      Baltimore
# 6               Female        12.0       Mallory        Center   Carol Stream
# 7                 Male       530.0          Erie         Plaza    Kansas City
# 8               Female       745.0      Annamark        Street      Fairbanks
# 9               Female         2.0          Pond          Hill    New Orleans
# 10                Male       221.0      Sauthoff          Pass      Bradenton
# 11              Female         5.0           NaN           NaN      Baltimore
# 12                Male         9.0   Eagle Crest        Center          Bronx
# 13              Female     71865.0   Valley Edge         Place     Washington
# 14              Female     71865.0     Claremont         Place    Los Angeles
# 15                Male     50948.0       Rowland         Alley     Charleston
# 16              Female      6817.0          Orin      Junction     San Rafael
# 17                Male      6817.0  Northwestern           Way       Amarillo
# 18                Male         8.0      Ridgeway          Park  Silver Spring
# 19              Female       249.0         Esker          Hill    San Antonio
# 20                Male       249.0      Grayhawk         Place        Houston
# 21                Male         1.0       Artisan      Junction    Gainesville
# 22              Female         1.0     Transport       Terrace         Duluth
# 23              Female         1.0        Shopko        Center         Denton
# 24                Male         9.0      Victoria         Trail     Washington
# 25                Male     97670.0    Kensington        Center        Houston
# 26              Female      2352.0      American           Way        Seattle
# 27                Male       573.0      Dovetail        Center         Sparks
# 28              Female      9296.0       Hanover          Road     Fort Wayne
# 29              Female       437.0    Pierstorff           Way     Pittsburgh
# 30                Male      6124.0         Kropf        Street    Los Angeles
# 31              Female      2385.0        Blaine         Trail        Augusta
# 32              Female      2385.0       Mallory           Way     Fort Wayne
# 33              Female      2385.0          Cody         Court         Dallas
# 34                Male         1.0           NaN           NaN            NaN
# 35                Male         4.0         Susan        Center     Washington
# 36              Female       127.0   Mockingbird          Hill     Washington
# 37              Female      7444.0  Northwestern      Crossing        Lansing
# 38                Male        76.0  Summer Ridge         Place        Atlanta
# 39                Male        76.0   Park Meadow          Pass    San Antonio
#
#                                state  postcode              full_name
# firstCustomer             California   92127.0       Romain Southcott
# secondCustomer                 Texas       NaN       Cosimo Molyneaux
# 2                              Texas   78220.0          Bambi Westrip
# 3                          Tennessee   38150.0      Roarke Pankettman
# 4                                NaN   83732.0       Mikaela Althorpe
# 5                           Maryland   21229.0       Magdalena Cullip
# 6                           Illinois   60351.0        Marietta Heball
# 7                           Missouri   64193.0         Tine McSperrin
# 8                             Alaska   99709.0  Enrichetta de Villier
# 9                          Louisiana       NaN           Sari Poulden
# 10                           Florida   34205.0         Natale Martina
# 11                          Maryland   21282.0        Noni Norrington
# 12                          New York   10469.0          Mikol MacWhan
# 13              District of Columbia   20456.0           Deny Thraves
# 14                        California   90005.0          Fara Petegrew
# 15                    South Carolina   29424.0    Jodie De Cristoforo
# 16                               NaN       NaN           Tobi Dewicke
# 17                             Texas   79118.0     Reinhold Woolforde
# 18                          Maryland   20910.0           Fredek Foley
# 19                             Texas   78210.0        Rubina Hustings
# 20                             Texas       NaN          Karim Woosnam
# 21                               NaN       NaN          Woodrow Fidoe
# 22                               NaN   30195.0        Loralie Normand
# 23                             Texas   76205.0       Danita Cleynaert
# 24              District of Columbia   20409.0       Tomlin Massinger
# 25                             Texas   77240.0        Franklin Goodge
# 26                        Washington   98127.0         Harlene Rameau
# 27                            Nevada   89436.0      Brander Quinnelly
# 28                           Indiana   46814.0         Jeanna Bruntje
# 29                      Pennsylvania       NaN            Ardyth Zack
# 30                        California   90065.0        Steve Pantridge
# 31                           Georgia       NaN             Brit Nouch
# 32                           Indiana   46896.0         Caril Barnsley
# 33                             Texas   75226.0       Rosalynd Dyerson
# 34                          Virginia   22070.0          Griffy Sonley
# 35              District of Columbia   20231.0           Ernest Armal
# 36              District of Columbia       NaN         Elspeth Mendus
# 37                          Michigan   48912.0        Clarita Bussons
# 38                           Georgia   31119.0       Stanislas Hacaud
# 39                             Texas   78260.0         Melvyn Seifert

# %% [markdown]
# Can you apply the similar strategy of ffill() in the street_name and street_suffix column as well.

# %%
data['street_name'].fillna(method='ffill', inplace=True)
data['street_suffix'].fillna(method='ffill', inplace=True)
# Out:
# <ipython-input-54-7a50f339a9c1>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['street_name'].fillna(method='ffill', inplace=True)
# <ipython-input-54-7a50f339a9c1>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['street_name'].fillna(method='ffill', inplace=True)
# <ipython-input-54-7a50f339a9c1>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['street_suffix'].fillna(method='ffill', inplace=True)
# <ipython-input-54-7a50f339a9c1>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['street_suffix'].fillna(method='ffill', inplace=True)

# %%
data.isnull().sum()
# Out:
# id                 0
# first_name         0
# last_name          0
# email            122
# gender             0
# street_num         0
# street_name        0
# street_suffix      0
# city              79
# state             80
# postcode         157
# full_name          0
# dtype: int64

# %%
data.head(40)
# Out:
#                 id  first_name      last_name                        email  \
# firstCustomer    1      Romain      Southcott    rsouthcott0@clickbank.net
# secondCustomer   2      Cosimo      Molyneaux        cmolyneaux1@wiley.com
# 2                3       Bambi        Westrip       bwestrip2@symantec.com
# 3                4      Roarke     Pankettman       rpankettman3@wiley.com
# 4                5     Mikaela       Althorpe             malthorpe4@51.la
# 5                6   Magdalena         Cullip             mcullip5@tiny.cc
# 6                7    Marietta         Heball            mheball6@blog.com
# 7                8        Tine      McSperrin  tmcsperrin7@statcounter.com
# 8                9  Enrichetta     de Villier         edevillier8@ox.ac.uk
# 9               10        Sari        Poulden           spoulden9@xing.com
# 10              11      Natale        Martina      nmartinaa@wordpress.com
# 11              12        Noni     Norrington    nnorringtonb@netvibes.com
# 12              13       Mikol        MacWhan          mmacwhanc@patch.com
# 13              14        Deny        Thraves            dthravesd@ibm.com
# 14              15        Fara       Petegrew          fpetegrewe@ebay.com
# 15              16       Jodie  De Cristoforo       jdecristoforof@mac.com
# 16              17        Tobi        Dewicke      tdewickeg@hostgator.com
# 17              18    Reinhold      Woolforde           rwoolfordeh@cbc.ca
# 18              19      Fredek          Foley              ffoleyi@bbb.org
# 19              20      Rubina       Hustings     rhustingsj@wikimedia.org
# 20              21       Karim        Woosnam          kwoosnamk@ifeng.com
# 21              22     Woodrow          Fidoe  wfidoel@creativecommons.org
# 22              23     Loralie        Normand            lnormandm@usa.gov
# 23              24      Danita      Cleynaert      dcleynaertn@t-online.de
# 24              25      Tomlin      Massinger                          NaN
# 25              26    Franklin         Goodge        fgoodgep@mapquest.com
# 26              27     Harlene         Rameau     hrameauq@squarespace.com
# 27              28     Brander      Quinnelly    bquinnellyr@shinystat.com
# 28              29      Jeanna        Bruntje      jbruntjes@tuttocitta.it
# 29              30      Ardyth           Zack         azackt@wordpress.com
# 30              31       Steve      Pantridge                          NaN
# 31              32        Brit          Nouch            bnouchv@yahoo.com
# 32              33       Caril       Barnsley    cbarnsleyw@bravesites.com
# 33              34    Rosalynd        Dyerson       rdyersonx@geocities.jp
# 34              35      Griffy         Sonley      gsonleyy@deviantart.com
# 35              36      Ernest          Armal      earmalz@dailymail.co.uk
# 36              37     Elspeth         Mendus          emendus10@ocn.ne.jp
# 37              38     Clarita        Bussons   cbussons11@marketwatch.com
# 38              39   Stanislas         Hacaud                          NaN
# 39              40      Melvyn        Seifert   mseifert13@photobucket.com
#
#                 gender  street_num   street_name street_suffix           city  \
# firstCustomer     Male         1.0     Trailsway          Road      San Diego
# secondCustomer    Male         1.0     Trailsway          Road        El Paso
# 2               Female      4057.0      Arkansas        Circle    San Antonio
# 3                 Male        74.0          Debs         Point        Memphis
# 4                 Male        74.0           2nd         Drive            NaN
# 5               Female      9190.0       Packers         Drive      Baltimore
# 6               Female        12.0       Mallory        Center   Carol Stream
# 7                 Male       530.0          Erie         Plaza    Kansas City
# 8               Female       745.0      Annamark        Street      Fairbanks
# 9               Female         2.0          Pond          Hill    New Orleans
# 10                Male       221.0      Sauthoff          Pass      Bradenton
# 11              Female         5.0      Sauthoff          Pass      Baltimore
# 12                Male         9.0   Eagle Crest        Center          Bronx
# 13              Female     71865.0   Valley Edge         Place     Washington
# 14              Female     71865.0     Claremont         Place    Los Angeles
# 15                Male     50948.0       Rowland         Alley     Charleston
# 16              Female      6817.0          Orin      Junction     San Rafael
# 17                Male      6817.0  Northwestern           Way       Amarillo
# 18                Male         8.0      Ridgeway          Park  Silver Spring
# 19              Female       249.0         Esker          Hill    San Antonio
# 20                Male       249.0      Grayhawk         Place        Houston
# 21                Male         1.0       Artisan      Junction    Gainesville
# 22              Female         1.0     Transport       Terrace         Duluth
# 23              Female         1.0        Shopko        Center         Denton
# 24                Male         9.0      Victoria         Trail     Washington
# 25                Male     97670.0    Kensington        Center        Houston
# 26              Female      2352.0      American           Way        Seattle
# 27                Male       573.0      Dovetail        Center         Sparks
# 28              Female      9296.0       Hanover          Road     Fort Wayne
# 29              Female       437.0    Pierstorff           Way     Pittsburgh
# 30                Male      6124.0         Kropf        Street    Los Angeles
# 31              Female      2385.0        Blaine         Trail        Augusta
# 32              Female      2385.0       Mallory           Way     Fort Wayne
# 33              Female      2385.0          Cody         Court         Dallas
# 34                Male         1.0          Cody         Court            NaN
# 35                Male         4.0         Susan        Center     Washington
# 36              Female       127.0   Mockingbird          Hill     Washington
# 37              Female      7444.0  Northwestern      Crossing        Lansing
# 38                Male        76.0  Summer Ridge         Place        Atlanta
# 39                Male        76.0   Park Meadow          Pass    San Antonio
#
#                                state  postcode              full_name
# firstCustomer             California   92127.0       Romain Southcott
# secondCustomer                 Texas       NaN       Cosimo Molyneaux
# 2                              Texas   78220.0          Bambi Westrip
# 3                          Tennessee   38150.0      Roarke Pankettman
# 4                                NaN   83732.0       Mikaela Althorpe
# 5                           Maryland   21229.0       Magdalena Cullip
# 6                           Illinois   60351.0        Marietta Heball
# 7                           Missouri   64193.0         Tine McSperrin
# 8                             Alaska   99709.0  Enrichetta de Villier
# 9                          Louisiana       NaN           Sari Poulden
# 10                           Florida   34205.0         Natale Martina
# 11                          Maryland   21282.0        Noni Norrington
# 12                          New York   10469.0          Mikol MacWhan
# 13              District of Columbia   20456.0           Deny Thraves
# 14                        California   90005.0          Fara Petegrew
# 15                    South Carolina   29424.0    Jodie De Cristoforo
# 16                               NaN       NaN           Tobi Dewicke
# 17                             Texas   79118.0     Reinhold Woolforde
# 18                          Maryland   20910.0           Fredek Foley
# 19                             Texas   78210.0        Rubina Hustings
# 20                             Texas       NaN          Karim Woosnam
# 21                               NaN       NaN          Woodrow Fidoe
# 22                               NaN   30195.0        Loralie Normand
# 23                             Texas   76205.0       Danita Cleynaert
# 24              District of Columbia   20409.0       Tomlin Massinger
# 25                             Texas   77240.0        Franklin Goodge
# 26                        Washington   98127.0         Harlene Rameau
# 27                            Nevada   89436.0      Brander Quinnelly
# 28                           Indiana   46814.0         Jeanna Bruntje
# 29                      Pennsylvania       NaN            Ardyth Zack
# 30                        California   90065.0        Steve Pantridge
# 31                           Georgia       NaN             Brit Nouch
# 32                           Indiana   46896.0         Caril Barnsley
# 33                             Texas   75226.0       Rosalynd Dyerson
# 34                          Virginia   22070.0          Griffy Sonley
# 35              District of Columbia   20231.0           Ernest Armal
# 36              District of Columbia       NaN         Elspeth Mendus
# 37                          Michigan   48912.0        Clarita Bussons
# 38                           Georgia   31119.0       Stanislas Hacaud
# 39                             Texas   78260.0         Melvyn Seifert

# %%
data['city'].fillna(method='bfill', inplace=True)
data['state'].fillna(method='bfill', inplace=True)
data['postcode'].fillna(method='bfill', inplace=True)

data.head(40)
# Out:
# <ipython-input-57-ecb511bb17bc>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['city'].fillna(method='bfill', inplace=True)
# <ipython-input-57-ecb511bb17bc>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['city'].fillna(method='bfill', inplace=True)
# <ipython-input-57-ecb511bb17bc>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['state'].fillna(method='bfill', inplace=True)
# <ipython-input-57-ecb511bb17bc>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['state'].fillna(method='bfill', inplace=True)
# <ipython-input-57-ecb511bb17bc>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['postcode'].fillna(method='bfill', inplace=True)
# <ipython-input-57-ecb511bb17bc>:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['postcode'].fillna(method='bfill', inplace=True)
#                 id  first_name      last_name                        email  \
# firstCustomer    1      Romain      Southcott    rsouthcott0@clickbank.net
# secondCustomer   2      Cosimo      Molyneaux        cmolyneaux1@wiley.com
# 2                3       Bambi        Westrip       bwestrip2@symantec.com
# 3                4      Roarke     Pankettman       rpankettman3@wiley.com
# 4                5     Mikaela       Althorpe             malthorpe4@51.la
# 5                6   Magdalena         Cullip             mcullip5@tiny.cc
# 6                7    Marietta         Heball            mheball6@blog.com
# 7                8        Tine      McSperrin  tmcsperrin7@statcounter.com
# 8                9  Enrichetta     de Villier         edevillier8@ox.ac.uk
# 9               10        Sari        Poulden           spoulden9@xing.com
# 10              11      Natale        Martina      nmartinaa@wordpress.com
# 11              12        Noni     Norrington    nnorringtonb@netvibes.com
# 12              13       Mikol        MacWhan          mmacwhanc@patch.com
# 13              14        Deny        Thraves            dthravesd@ibm.com
# 14              15        Fara       Petegrew          fpetegrewe@ebay.com
# 15              16       Jodie  De Cristoforo       jdecristoforof@mac.com
# 16              17        Tobi        Dewicke      tdewickeg@hostgator.com
# 17              18    Reinhold      Woolforde           rwoolfordeh@cbc.ca
# 18              19      Fredek          Foley              ffoleyi@bbb.org
# 19              20      Rubina       Hustings     rhustingsj@wikimedia.org
# 20              21       Karim        Woosnam          kwoosnamk@ifeng.com
# 21              22     Woodrow          Fidoe  wfidoel@creativecommons.org
# 22              23     Loralie        Normand            lnormandm@usa.gov
# 23              24      Danita      Cleynaert      dcleynaertn@t-online.de
# 24              25      Tomlin      Massinger                          NaN
# 25              26    Franklin         Goodge        fgoodgep@mapquest.com
# 26              27     Harlene         Rameau     hrameauq@squarespace.com
# 27              28     Brander      Quinnelly    bquinnellyr@shinystat.com
# 28              29      Jeanna        Bruntje      jbruntjes@tuttocitta.it
# 29              30      Ardyth           Zack         azackt@wordpress.com
# 30              31       Steve      Pantridge                          NaN
# 31              32        Brit          Nouch            bnouchv@yahoo.com
# 32              33       Caril       Barnsley    cbarnsleyw@bravesites.com
# 33              34    Rosalynd        Dyerson       rdyersonx@geocities.jp
# 34              35      Griffy         Sonley      gsonleyy@deviantart.com
# 35              36      Ernest          Armal      earmalz@dailymail.co.uk
# 36              37     Elspeth         Mendus          emendus10@ocn.ne.jp
# 37              38     Clarita        Bussons   cbussons11@marketwatch.com
# 38              39   Stanislas         Hacaud                          NaN
# 39              40      Melvyn        Seifert   mseifert13@photobucket.com
#
#                 gender  street_num   street_name street_suffix           city  \
# firstCustomer     Male         1.0     Trailsway          Road      San Diego
# secondCustomer    Male         1.0     Trailsway          Road        El Paso
# 2               Female      4057.0      Arkansas        Circle    San Antonio
# 3                 Male        74.0          Debs         Point        Memphis
# 4                 Male        74.0           2nd         Drive      Baltimore
# 5               Female      9190.0       Packers         Drive      Baltimore
# 6               Female        12.0       Mallory        Center   Carol Stream
# 7                 Male       530.0          Erie         Plaza    Kansas City
# 8               Female       745.0      Annamark        Street      Fairbanks
# 9               Female         2.0          Pond          Hill    New Orleans
# 10                Male       221.0      Sauthoff          Pass      Bradenton
# 11              Female         5.0      Sauthoff          Pass      Baltimore
# 12                Male         9.0   Eagle Crest        Center          Bronx
# 13              Female     71865.0   Valley Edge         Place     Washington
# 14              Female     71865.0     Claremont         Place    Los Angeles
# 15                Male     50948.0       Rowland         Alley     Charleston
# 16              Female      6817.0          Orin      Junction     San Rafael
# 17                Male      6817.0  Northwestern           Way       Amarillo
# 18                Male         8.0      Ridgeway          Park  Silver Spring
# 19              Female       249.0         Esker          Hill    San Antonio
# 20                Male       249.0      Grayhawk         Place        Houston
# 21                Male         1.0       Artisan      Junction    Gainesville
# 22              Female         1.0     Transport       Terrace         Duluth
# 23              Female         1.0        Shopko        Center         Denton
# 24                Male         9.0      Victoria         Trail     Washington
# 25                Male     97670.0    Kensington        Center        Houston
# 26              Female      2352.0      American           Way        Seattle
# 27                Male       573.0      Dovetail        Center         Sparks
# 28              Female      9296.0       Hanover          Road     Fort Wayne
# 29              Female       437.0    Pierstorff           Way     Pittsburgh
# 30                Male      6124.0         Kropf        Street    Los Angeles
# 31              Female      2385.0        Blaine         Trail        Augusta
# 32              Female      2385.0       Mallory           Way     Fort Wayne
# 33              Female      2385.0          Cody         Court         Dallas
# 34                Male         1.0          Cody         Court     Washington
# 35                Male         4.0         Susan        Center     Washington
# 36              Female       127.0   Mockingbird          Hill     Washington
# 37              Female      7444.0  Northwestern      Crossing        Lansing
# 38                Male        76.0  Summer Ridge         Place        Atlanta
# 39                Male        76.0   Park Meadow          Pass    San Antonio
#
#                                state  postcode              full_name
# firstCustomer             California   92127.0       Romain Southcott
# secondCustomer                 Texas   78220.0       Cosimo Molyneaux
# 2                              Texas   78220.0          Bambi Westrip
# 3                          Tennessee   38150.0      Roarke Pankettman
# 4                           Maryland   83732.0       Mikaela Althorpe
# 5                           Maryland   21229.0       Magdalena Cullip
# 6                           Illinois   60351.0        Marietta Heball
# 7                           Missouri   64193.0         Tine McSperrin
# 8                             Alaska   99709.0  Enrichetta de Villier
# 9                          Louisiana   34205.0           Sari Poulden
# 10                           Florida   34205.0         Natale Martina
# 11                          Maryland   21282.0        Noni Norrington
# 12                          New York   10469.0          Mikol MacWhan
# 13              District of Columbia   20456.0           Deny Thraves
# 14                        California   90005.0          Fara Petegrew
# 15                    South Carolina   29424.0    Jodie De Cristoforo
# 16                             Texas   79118.0           Tobi Dewicke
# 17                             Texas   79118.0     Reinhold Woolforde
# 18                          Maryland   20910.0           Fredek Foley
# 19                             Texas   78210.0        Rubina Hustings
# 20                             Texas   30195.0          Karim Woosnam
# 21                             Texas   30195.0          Woodrow Fidoe
# 22                             Texas   30195.0        Loralie Normand
# 23                             Texas   76205.0       Danita Cleynaert
# 24              District of Columbia   20409.0       Tomlin Massinger
# 25                             Texas   77240.0        Franklin Goodge
# 26                        Washington   98127.0         Harlene Rameau
# 27                            Nevada   89436.0      Brander Quinnelly
# 28                           Indiana   46814.0         Jeanna Bruntje
# 29                      Pennsylvania   90065.0            Ardyth Zack
# 30                        California   90065.0        Steve Pantridge
# 31                           Georgia   46896.0             Brit Nouch
# 32                           Indiana   46896.0         Caril Barnsley
# 33                             Texas   75226.0       Rosalynd Dyerson
# 34                          Virginia   22070.0          Griffy Sonley
# 35              District of Columbia   20231.0           Ernest Armal
# 36              District of Columbia   48912.0         Elspeth Mendus
# 37                          Michigan   48912.0        Clarita Bussons
# 38                           Georgia   31119.0       Stanislas Hacaud
# 39                             Texas   78260.0         Melvyn Seifert

# %%
data.isnull().sum()
# Out:
# id                 0
# first_name         0
# last_name          0
# email            122
# gender             0
# street_num         0
# street_name        0
# street_suffix      0
# city               0
# state              0
# postcode           0
# full_name          0
# dtype: int64

# %%
data['email'].fillna('Unknown', inplace=True)
data.head(40)
# Out:
# <ipython-input-59-62b6115176ef>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['email'].fillna('Unknown', inplace=True)
#                 id  first_name      last_name                        email  \
# firstCustomer    1      Romain      Southcott    rsouthcott0@clickbank.net
# secondCustomer   2      Cosimo      Molyneaux        cmolyneaux1@wiley.com
# 2                3       Bambi        Westrip       bwestrip2@symantec.com
# 3                4      Roarke     Pankettman       rpankettman3@wiley.com
# 4                5     Mikaela       Althorpe             malthorpe4@51.la
# 5                6   Magdalena         Cullip             mcullip5@tiny.cc
# 6                7    Marietta         Heball            mheball6@blog.com
# 7                8        Tine      McSperrin  tmcsperrin7@statcounter.com
# 8                9  Enrichetta     de Villier         edevillier8@ox.ac.uk
# 9               10        Sari        Poulden           spoulden9@xing.com
# 10              11      Natale        Martina      nmartinaa@wordpress.com
# 11              12        Noni     Norrington    nnorringtonb@netvibes.com
# 12              13       Mikol        MacWhan          mmacwhanc@patch.com
# 13              14        Deny        Thraves            dthravesd@ibm.com
# 14              15        Fara       Petegrew          fpetegrewe@ebay.com
# 15              16       Jodie  De Cristoforo       jdecristoforof@mac.com
# 16              17        Tobi        Dewicke      tdewickeg@hostgator.com
# 17              18    Reinhold      Woolforde           rwoolfordeh@cbc.ca
# 18              19      Fredek          Foley              ffoleyi@bbb.org
# 19              20      Rubina       Hustings     rhustingsj@wikimedia.org
# 20              21       Karim        Woosnam          kwoosnamk@ifeng.com
# 21              22     Woodrow          Fidoe  wfidoel@creativecommons.org
# 22              23     Loralie        Normand            lnormandm@usa.gov
# 23              24      Danita      Cleynaert      dcleynaertn@t-online.de
# 24              25      Tomlin      Massinger                      Unknown
# 25              26    Franklin         Goodge        fgoodgep@mapquest.com
# 26              27     Harlene         Rameau     hrameauq@squarespace.com
# 27              28     Brander      Quinnelly    bquinnellyr@shinystat.com
# 28              29      Jeanna        Bruntje      jbruntjes@tuttocitta.it
# 29              30      Ardyth           Zack         azackt@wordpress.com
# 30              31       Steve      Pantridge                      Unknown
# 31              32        Brit          Nouch            bnouchv@yahoo.com
# 32              33       Caril       Barnsley    cbarnsleyw@bravesites.com
# 33              34    Rosalynd        Dyerson       rdyersonx@geocities.jp
# 34              35      Griffy         Sonley      gsonleyy@deviantart.com
# 35              36      Ernest          Armal      earmalz@dailymail.co.uk
# 36              37     Elspeth         Mendus          emendus10@ocn.ne.jp
# 37              38     Clarita        Bussons   cbussons11@marketwatch.com
# 38              39   Stanislas         Hacaud                      Unknown
# 39              40      Melvyn        Seifert   mseifert13@photobucket.com
#
#                 gender  street_num   street_name street_suffix           city  \
# firstCustomer     Male         1.0     Trailsway          Road      San Diego
# secondCustomer    Male         1.0     Trailsway          Road        El Paso
# 2               Female      4057.0      Arkansas        Circle    San Antonio
# 3                 Male        74.0          Debs         Point        Memphis
# 4                 Male        74.0           2nd         Drive      Baltimore
# 5               Female      9190.0       Packers         Drive      Baltimore
# 6               Female        12.0       Mallory        Center   Carol Stream
# 7                 Male       530.0          Erie         Plaza    Kansas City
# 8               Female       745.0      Annamark        Street      Fairbanks
# 9               Female         2.0          Pond          Hill    New Orleans
# 10                Male       221.0      Sauthoff          Pass      Bradenton
# 11              Female         5.0      Sauthoff          Pass      Baltimore
# 12                Male         9.0   Eagle Crest        Center          Bronx
# 13              Female     71865.0   Valley Edge         Place     Washington
# 14              Female     71865.0     Claremont         Place    Los Angeles
# 15                Male     50948.0       Rowland         Alley     Charleston
# 16              Female      6817.0          Orin      Junction     San Rafael
# 17                Male      6817.0  Northwestern           Way       Amarillo
# 18                Male         8.0      Ridgeway          Park  Silver Spring
# 19              Female       249.0         Esker          Hill    San Antonio
# 20                Male       249.0      Grayhawk         Place        Houston
# 21                Male         1.0       Artisan      Junction    Gainesville
# 22              Female         1.0     Transport       Terrace         Duluth
# 23              Female         1.0        Shopko        Center         Denton
# 24                Male         9.0      Victoria         Trail     Washington
# 25                Male     97670.0    Kensington        Center        Houston
# 26              Female      2352.0      American           Way        Seattle
# 27                Male       573.0      Dovetail        Center         Sparks
# 28              Female      9296.0       Hanover          Road     Fort Wayne
# 29              Female       437.0    Pierstorff           Way     Pittsburgh
# 30                Male      6124.0         Kropf        Street    Los Angeles
# 31              Female      2385.0        Blaine         Trail        Augusta
# 32              Female      2385.0       Mallory           Way     Fort Wayne
# 33              Female      2385.0          Cody         Court         Dallas
# 34                Male         1.0          Cody         Court     Washington
# 35                Male         4.0         Susan        Center     Washington
# 36              Female       127.0   Mockingbird          Hill     Washington
# 37              Female      7444.0  Northwestern      Crossing        Lansing
# 38                Male        76.0  Summer Ridge         Place        Atlanta
# 39                Male        76.0   Park Meadow          Pass    San Antonio
#
#                                state  postcode              full_name
# firstCustomer             California   92127.0       Romain Southcott
# secondCustomer                 Texas   78220.0       Cosimo Molyneaux
# 2                              Texas   78220.0          Bambi Westrip
# 3                          Tennessee   38150.0      Roarke Pankettman
# 4                           Maryland   83732.0       Mikaela Althorpe
# 5                           Maryland   21229.0       Magdalena Cullip
# 6                           Illinois   60351.0        Marietta Heball
# 7                           Missouri   64193.0         Tine McSperrin
# 8                             Alaska   99709.0  Enrichetta de Villier
# 9                          Louisiana   34205.0           Sari Poulden
# 10                           Florida   34205.0         Natale Martina
# 11                          Maryland   21282.0        Noni Norrington
# 12                          New York   10469.0          Mikol MacWhan
# 13              District of Columbia   20456.0           Deny Thraves
# 14                        California   90005.0          Fara Petegrew
# 15                    South Carolina   29424.0    Jodie De Cristoforo
# 16                             Texas   79118.0           Tobi Dewicke
# 17                             Texas   79118.0     Reinhold Woolforde
# 18                          Maryland   20910.0           Fredek Foley
# 19                             Texas   78210.0        Rubina Hustings
# 20                             Texas   30195.0          Karim Woosnam
# 21                             Texas   30195.0          Woodrow Fidoe
# 22                             Texas   30195.0        Loralie Normand
# 23                             Texas   76205.0       Danita Cleynaert
# 24              District of Columbia   20409.0       Tomlin Massinger
# 25                             Texas   77240.0        Franklin Goodge
# 26                        Washington   98127.0         Harlene Rameau
# 27                            Nevada   89436.0      Brander Quinnelly
# 28                           Indiana   46814.0         Jeanna Bruntje
# 29                      Pennsylvania   90065.0            Ardyth Zack
# 30                        California   90065.0        Steve Pantridge
# 31                           Georgia   46896.0             Brit Nouch
# 32                           Indiana   46896.0         Caril Barnsley
# 33                             Texas   75226.0       Rosalynd Dyerson
# 34                          Virginia   22070.0          Griffy Sonley
# 35              District of Columbia   20231.0           Ernest Armal
# 36              District of Columbia   48912.0         Elspeth Mendus
# 37                          Michigan   48912.0        Clarita Bussons
# 38                           Georgia   31119.0       Stanislas Hacaud
# 39                             Texas   78260.0         Melvyn Seifert

# %%
data_products.isnull().sum()
# Out:
# id         0
# product    0
# cost       0
# company    5
# dtype: int64

# %% [markdown]
# Can you impute the missing values of the company with the 'Unknown'

# %%
data_products['company'].fillna('Unknown', inplace=True)
data_products.isnull().sum()
# Out:
# <ipython-input-61-c2b19ed25efb>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_products['company'].fillna('Unknown', inplace=True)
# id         0
# product    0
# cost       0
# company    0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# id               0
# first_name       0
# last_name        0
# email            0
# gender           0
# street_num       0
# street_name      0
# street_suffix    0
# city             0
# state            0
# postcode         0
# full_name        0
# dtype: int64

# %%
data_purchases.isnull().sum()
# Out:
# id              0
# purch_date      0
# customer_num    0
# product_num     0
# amount          0
# paid            0
# dtype: int64

# %%
data.to_excel('customers.xlsx')
data_purchases.to_excel('purchases.xlsx')
data_products.to_excel('products.xlsx')

# %% [markdown]
# Data Analysis: Aggregation

# %% [markdown]
# Group by 'customer_num' and compute the sum of 'amount' and 'paid' column

# %%
data_purchases.head(10)
# Out:
#    id purch_date  customer_num  product_num  amount     paid
# 0   1 2019-01-03           823           27      12   568.92
# 1   2 2019-01-03           606           28      14   395.36
# 2   3 2019-01-03           955            9      17   510.17
# 3   4 2019-01-03           577           19       3    68.49
# 4   5 2019-01-03           429            8      18   759.42
# 5   6 2019-01-03           275           36      18   176.76
# 6   7 2019-01-03           456           21      10   904.80
# 7   8 2019-01-03           526           58      19  1387.95
# 8   9 2019-01-03           326           44       2    61.34
# 9  10 2019-01-03            13           21       5   316.70

# %%
aggregated_purchase = data_purchases.groupby('customer_num').agg({'amount':'sum', 'paid': 'sum'})
print(aggregated_purchase)
# Out:
#               amount     paid
# customer_num
# 1                 24   779.34
# 2                 67  3978.09
# 3                 88  5031.39
# 4                 38  2276.38
# 5                 46  2931.24
# ...              ...      ...
# 996               31  2339.19
# 997               55  3030.34
# 998               69  3346.93
# 999               66  3640.48
# 1000              75  3961.63
#
# [997 rows x 2 columns]

# %% [markdown]
# Can you give me the total amount and total paid as per the purchase_date.

# %%
aggregated_purchase_date = data_purchases.groupby('purch_date').agg({'amount':'sum', 'paid':'sum'})
aggregated_purchase_date
# Out:
#             amount      paid
# purch_date
# 2019-01-03     480  20468.33
# 2019-01-04     872  48529.13
# 2019-01-05     715  38643.67
# 2019-01-06     576  32345.29
# 2019-02-03     568  28183.50
# ...            ...       ...
# 2019-11-06     475  24778.05
# 2019-12-03     524  27691.62
# 2019-12-04     647  37100.59
# 2019-12-05     380  20845.55
# 2019-12-06     481  26410.08
#
# [108 rows x 2 columns]

# %% [markdown]
# Task: Please explore the method drop_duplicates
